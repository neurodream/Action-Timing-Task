# %%
from BFTUSk.analysis import *
from BFTUSk.sim_task import *

# %%
plot_simulation(
    ["random", "early", "middle", "late"], 
    ['grey', 'green', 'orange', 'darkred']
    )

# %%
plot_simulation(
    ["early", "strategy1"], 
    ['green', [0.2, 0.2, 1]]
    )

# %%
best_vals, best_score = optimize_float_vals(n_iter=10_000)
df, score, _ = run_sim(float_vals=best_vals)     # ~20-40 % > “early”
plot_best_vals(best_vals)
# Out:
# 100%|██████████| 10000/10000 [14:36<00:00, 11.41it/s]
# <Axes: xlabel='reward_magnitude index', ylabel='p_end index'>

# %%
# TODO fit a normal distribution during each break
